# %%
# !pip install transformers datasets torch accelerate

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
prompt = "Artificial Intelligence is"

result = generator(
    prompt,
    max_length=100,
    num_return_sequences=3
)

for i, output in enumerate(result):
    print(f"\nOutput {i+1}")
    print(output["generated_text"])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Output 1
# Artificial Intelligence is a fundamental part of human intelligence. We need to understand what it is that we can learn.
#
# We have learned what we can learn at other times. We have learned that this experience is not what it seems.
#
# There is no truth in the notion that AI is not going to change anything. It is going to be the future of humanity.
#
# The fact that we are not going to be able to learn is a major problem. The more we work to understand AI the more we will realize that it will be a better technology than we understand.
#
# ...

# %%
dataset_text = """
Artificial Intelligence is transforming industries worldwide.
Machine learning helps computers learn from data.
Deep learning uses neural networks to solve complex problems.
Generative AI can create text, images, and code.
Python is a popular programming language for AI.
Data analytics helps organizations make informed decisions.
Large language models understand and generate human language.
AI is widely used in healthcare and education.
Business intelligence converts data into useful insights.
Data science combines statistics and programming.
AI-powered systems improve customer experiences.
Machine learning models require quality datasets.
Neural networks are inspired by the human brain.
Automation reduces repetitive manual work.
AI assists in fraud detection and cybersecurity.
Computer vision enables machines to understand images.
Natural language processing helps computers understand text.
Chatbots provide instant customer support.
Predictive analytics helps forecast future trends.
Cloud computing supports large-scale AI applications.
Data preprocessing improves model performance.
AI is changing the future of technology.
Smart systems learn from historical data.
Deep learning models require powerful hardware.
AI helps businesses make better decisions.
Data visualization makes complex information easier to understand.
Recommendation systems personalize user experiences.
AI is used in autonomous vehicles.
Big data plays a vital role in machine learning.
Generative models can create realistic content.
Technology continues to evolve rapidly.
Innovation drives digital transformation.
Artificial Intelligence enhances productivity.
AI solutions improve operational efficiency.
Data-driven decisions lead to better outcomes.
Machine learning is a subset of AI.
AI applications are growing every year.
Researchers develop advanced AI algorithms.
Digital technologies reshape industries worldwide.
Intelligent systems solve complex problems efficiently.
AI supports scientific discoveries.
"""

with open("ai_dataset.txt", "w") as f:
    f.write(dataset_text)

print("ai_dataset.txt created successfully!")
# Out:
# ai_dataset.txt created successfully!

# %%
# !ls
# Out:
# ai_dataset.txt	gpt2-finetuned	sample_data

# %%
sample_data = """
Artificial Intelligence is transforming industries worldwide.
Machine learning helps computers learn from data.
Deep learning uses neural networks to solve complex problems.
Generative AI can create text, images, and code.
Python is a popular programming language for AI.
Data analytics helps organizations make informed decisions.
Large language models understand and generate human language.
AI is widely used in healthcare and education.
Business intelligence converts data into useful insights.
Data science combines statistics and programming.
AI improves customer experience through automation.
Machine learning algorithms detect patterns in data.
Natural language processing enables machines to understand text.
Computer vision helps computers analyze images.
AI-powered chatbots assist users efficiently.
Data visualization makes information easier to understand.
Predictive analytics forecasts future trends.
Deep learning powers modern AI applications.
Artificial Intelligence is changing the future of technology.
Neural networks mimic the human brain.
AI helps businesses improve productivity.
Cloud computing supports AI applications.
Big data provides valuable information for AI models.
Recommendation systems personalize user experiences.
AI is used in self-driving cars.
Healthcare uses AI for disease prediction.
Educational platforms use AI for personalized learning.
Cybersecurity systems use AI to detect threats.
AI enhances decision-making processes.
Machine learning improves over time with more data.
Data engineers build data pipelines.
AI can automate repetitive tasks.
Generative AI creates creative content.
Large datasets improve model performance.
AI research continues to grow rapidly.
Technology companies invest heavily in AI.
AI assists scientists in data analysis.
Smart assistants use natural language processing.
Data quality is important for machine learning.
AI is revolutionizing many industries.
"""

# %%
with open("ai_dataset.txt", "w") as f:
    f.write(sample_data)

print("Dataset updated successfully!")
# Out:
# Dataset updated successfully!

# %%
with open("ai_dataset.txt", "w") as f:
    f.write(dataset_text)

# %%
with open("ai_dataset.txt", "r") as f:
    print(f.read())
# Out:
# Artificial Intelligence is transforming industries worldwide.
# Machine learning helps computers learn from data.
# Deep learning uses neural networks to solve complex problems.
# Generative AI can create text, images, and code.
# Python is a popular programming language for AI.
# Data analytics helps organizations make informed decisions.
# Large language models understand and generate human language.
# AI is widely used in healthcare and education.
# Business intelligence converts data into useful insights.
# Data science combines statistics and programming.
# AI-powered systems improve customer experiences.
# Machine learning models require quality datasets.
# Neural networks are inspired by the human brain.
# Automation reduces repetitive manual work.
# AI assists in fraud detection and cybersecurity.
# Computer vision enables machines to understand images.
# Natural language processing helps computers understand text.
# Chatbots provide instant customer support.
# ...

# %%
# !pip install -q transformers datasets accelerate

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

print("GPT-2 loaded successfully!")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT-2 loaded successfully!

# %%
from datasets import load_dataset

dataset = load_dataset(
    "text",
    data_files={"train": "ai_dataset.txt"}
)

print(dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 41
#     })
# })

# %%
print(dataset["train"][0])
# Out:
# {'text': ''}

# %%
sample_data = """
Artificial Intelligence is transforming industries worldwide.
Machine learning helps computers learn from data.
Deep learning uses neural networks to solve complex problems.
Generative AI can create text, images, and code.
Python is a popular programming language for AI.
Data analytics helps organizations make informed decisions.
Large language models understand and generate human language.
AI is widely used in healthcare and education.
Business intelligence converts data into useful insights.
Data science combines statistics and programming.
AI improves customer experience through automation.
Machine learning algorithms detect patterns in data.
Natural language processing enables machines to understand text.
Computer vision helps computers analyze images.
AI-powered chatbots assist users efficiently.
Data visualization makes information easier to understand.
Predictive analytics forecasts future trends.
Deep learning powers modern AI applications.
Artificial Intelligence is changing the future of technology.
Neural networks mimic the human brain.
AI helps businesses improve productivity.
Cloud computing supports AI applications.
Big data provides valuable information for AI models.
Recommendation systems personalize user experiences.
AI is used in self-driving cars.
Healthcare uses AI for disease prediction.
Educational platforms use AI for personalized learning.
Cybersecurity systems use AI to detect threats.
AI enhances decision-making processes.
Machine learning improves over time with more data.
Data engineers build data pipelines.
AI can automate repetitive tasks.
Generative AI creates creative content.
Large datasets improve model performance.
AI research continues to grow rapidly.
Technology companies invest heavily in AI.
AI assists scientists in data analysis.
Smart assistants use natural language processing.
Data quality is important for machine learning.
AI is revolutionizing many industries.
"""

# %%
tokenizer.pad_token = tokenizer.eos_token

print("Padding token fixed!")
# Out:
# Padding token fixed!

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        truncation=True,
        padding="max_length",
        max_length=128
    )

tokenized_dataset = dataset.map(
    tokenize_function,
    batched=True
)

print("Tokenization completed!")
# Out:
# Map:   0%|          | 0/41 [00:00<?, ? examples/s]
# Tokenization completed!

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)

print("Data Collator Created!")
# Out:
# Data Collator Created!

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./gpt2-finetuned",
    num_train_epochs=3,
    per_device_train_batch_size=2
)

print("Training Arguments Created!")
# Out:
# Training Arguments Created!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    data_collator=data_collator,
)

print("Trainer Created!")
# Out:
# Trainer Created!

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='50' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/63 04:17 < 01:09, 0.19 it/s, Epoch 2.33/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 05:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
# ...

# %%
prompt = "Artificial Intelligence"

output = model.generate(
    tokenizer(prompt, return_tensors="pt").input_ids,
    max_length=100,
    num_return_sequences=3,
    do_sample=True
)

for i, text in enumerate(output):
    print(f"\nOutput {i+1}:")
    print(tokenizer.decode(text, skip_special_tokens=True))
# Out:
# [transformers] The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Output 1:
# Artificial Intelligence improves productivity.
#
# AI improves productivity. AI models create efficient data into algorithms.
#
# AI enables machine learning.
#
# It saves lives. AI is transforming industries today. AI improves efficiency.
#
#
# AI improves efficiency in AI applications. For more than 100 companies worldwide, AI improves human-computer interfaces.
# AI's future technology is growing every year.
#
# ...

# %%
from google.colab import files
files.download("ai_dataset.txt")
